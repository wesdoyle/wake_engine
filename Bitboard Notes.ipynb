# %%
from board import Board

# %%
board = Board()

# %%
state = board.update_bitboard_state()

# %%
board.pretty_print_bitboard()
# Out:
# XXXXXXXX
# XXXXXXXX
# --------
# --------
# --------
# --------
# XXXXXXXX
# XXXXXXXX
